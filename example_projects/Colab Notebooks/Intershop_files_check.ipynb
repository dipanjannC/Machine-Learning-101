# %%
import pandas as pd
import numpy as np
pd.set_option('display.expand_frame_repr', False)

# %%
CUS_COLUMNS = ['CUSTOMER_CODE','CUSTOMER_DIVISION','SAP_ID','USER_DIVISION',
'KCUST_ID','LOGIN_NAME','LAST_NAME','FIRST_NAME','COMPANY_NAME','LOCATION','DEPARTMENT',
'POSTAL_CODE','ADDRESS1','ADDRESS2','ADDRESS3','ADDRESS4','PHONE','EXTENSION','HOMEPHONE',
'FAX','MAILADDRESS','GENDER','JOB_TITLE','BIRTHDAY','SEND_MAIL','SAP_BILL_TO_ID','SAP_SHIP_TO_ID',
'SAP_PAYER_ID','OMS_DISCOUNT','PRICE_TYPE','USER_CREATE_DATE','MODIFY_DATE','BACKLOGFLG',
'HP_SAP_SOLD_ID','HP_SAP_PAYER_ID','HP_BILL_TO_SAP_ID','HP_SHIP_TO_SAP_ID','EMPLOYEE_SCALE',
'INDUSTRY','JOBTYPE','MAIL_PERMIT','FAX_PERMIT','OPERATIONFLG','JOB',
'CORPORATION','CORPORATIONPOSITION','LASTMODIFIED','LASTNAMETRANSCRIPTION',
'FIRSTNAMETRANSCRIPTION','PERMITLASTMODIFIEDDATE','MASTERDPID','DEFAULTDPID',
'HPIDDPLUS_USERNAME','HPIDDPLUS_IDP']

# %%
MAIN_COLUMNS = ['QUOTE_NO','CUSTOMER_CODE','ORDER_STATUS','PAYMENT_TYPE','CREDIT_CARD_TYPE',
'QUOTE_DATE','QUOTE_TIME','ORDER_DATE','ORDER_TIME','CLEARANCE_DATE','CANCEL_DATE',
'SCHE_DELIVERY_DATE','DELIVERY_DATE','TOTAL_MONEY','PO_NO','REMARKS','QUOTE_DATA_SOURCE',
'ORDER_DATA_SOURCE','SAP_ORDER_NO','REFERENCE_NO','TELAQS_FEED','AGENT_ID','SAP_SOLD_ID',
'SAP_PAYER_ID','TRANSACTION_DATE','MODIFY_DATE','CUSTOMERREQUESTEDDELIVERYDATE','BACKLOGFLG',
'HP_SAP_SOLD_ID','HP_SAP_PAYER_ID','STANDARDREQUESTEDDELIVERYDATE','HP_UPDATE_SAP_SOLD_ID',
'OPERATIONFLG','CUSTOMERREQUESTEDDELIVERYTIME','PRODUCTRESERVEDTYPE','CUSTOMERCONFIRMATIONFLG',
'CURRENTLEVEL','PREVIOUSLEVEL','BIDSTATUS','DELAYSCHEDULEDDELIVERYDATE','SENDMAILFLG',
'ORIGINALDOCUMENTNO','PREVIOUSSCHEDULEDDELIVERYDATE','COMMENT2','NOTES','HEARTORDERNO',
'ORDERENTRYDATE','LOCATION','CLEARANCE_TIME','BOOKING_TIME','PLANNO','ENCLOSUREFLG',
'PROJECTID','ADMITSTATUS','APPILCANTCOMMENT','ADMITCOMMENT','BIGDNO','ENDUSERNAME',
'CAMPAIGNID','EXTEND1','EXTEND2','EXTEND3','EXTEND4','EXTEND5','EXTEND6','EXTEND7',
'EXTEND8','EXTEND9','EXTEND10','MASTERDPID','DEFAULTDPID','RISK','OFLG','MARGINGUIDELINENAME',
'FILEPATH','LASTMODIFIEDACCOUNT','LASTMODIFIED','APPROVALEXPIRATIONDATE','CONFLICT1','CONFLICT2',
'CONFLICT3','APPLICANT','APPLICANTDATE','APPLICANTTIME','ADMITGROUP','PARENTDOCUMENTNO','LBCCODE',
'HEADLBCCODE','TOPHEADLBCCODE','BILL_TO_CUSTOMER_LASTNAME','BILL_TO_CUSTOMER_FIRSTNAME',
'BILL_TO_CUSTOMER_COMPANY','BILL_TO_CUSTOMER_DEPARTMENT','BILL_TO_ADDRESS1','BILL_TO_ADDRESS2',
'BILL_TO_ADDRESS3','BILL_TO_ADDRESS4','BILL_TO_POSTAL_CODE','BILL_TO_PHONE','BILL_TO_HOMEPHONE',
'BILL_TO_FAX','BILL_TO_MAILADDRESS','BILL_TO_DIGITAL_ID','BILL_TO_SAP_ID','HP_BILL_TO_SAP_ID',
'SHIP_TO_CUSTOMER_LASTNAME','SHIP_TO_CUSTOMER_FIRSTNAME','SHIP_TO_CUSTOMER_COMPANY',
'SHIP_TO_CUSTOMER_DEPARTMENT','SHIP_TO_ADDRESS1','SHIP_TO_ADDRESS2','SHIP_TO_ADDRESS3',
'SHIP_TO_ADDRESS4','SHIP_TO_POSTAL_CODE','SHIP_TO_PHONE','SHIP_TO_SAP_ID','HP_SHIP_TO_SAP_ID',
'INSTALL_TO_LASTNAME','INSTALL_TO_FIRSTNAME','INSTALL_TO_COMPANY','INSTALL_TO_DEPARTMENT',
'INSTALL_TO_ADDRESS1','INSTALL_TO_ADDRESS2','INSTALL_TO_ADDRESS3','INSTALL_TO_ADDRESS4',
'INSTALL_TO_POSTAL_CODE','INSTALL_TO_PHONE','INSTALL_TO_FAX','INSTALL_TO_MAILADDRESS',
'INSTALL_TO_SERIAL_NO','INSTALL_TO_PART_NO','INSTALL_TO_PURCHASE_DATE','TELESELLER_NAME1',
'TELESELLER_NAME2','TELESELLER_NAME3','TELESELLER_NAME4','TELESELLER_NAME5']

# %%
customer_info_failed  = pd.read_csv('/content/Customer_Information_20211218.csv',sep=chr(29), encoding='utf-8',names = CUS_COLUMNS)

# %%
customer_info_failed
# Out:
#       CUSTOMER_CODE CUSTOMER_DIVISION  SAP_ID USER_DIVISION                  KCUST_ID           LOGIN_NAME LAST_NAME FIRST_NAME   COMPANY_NAME LOCATION          DEPARTMENT POSTAL_CODE ADDRESS1 ADDRESS2    ADDRESS3         ADDRESS4          PHONE  EXTENSION      HOMEPHONE           FAX                       MAILADDRESS    GENDER  JOB_TITLE    BIRTHDAY SEND_MAIL  SAP_BILL_TO_ID  SAP_SHIP_TO_ID  SAP_PAYER_ID  OMS_DISCOUNT  PRICE_TYPE USER_CREATE_DATE MODIFY_DATE  BACKLOGFLG  HP_SAP_SOLD_ID  HP_SAP_PAYER_ID  HP_BILL_TO_SAP_ID  HP_SHIP_TO_SAP_ID  EMPLOYEE_SCALE     INDUSTRY           JOBTYPE MAIL_PERMIT FAX_PERMIT OPERATIONFLG      JOB CORPORATION CORPORATIONPOSITION LASTMODIFIED LASTNAMETRANSCRIPTION FIRSTNAMETRANSCRIPTION PERMITLASTMODIFIEDDATE  MASTERDPID  DEFAULTDPID                HPIDDPLUS_USERNAME HPIDDPLUS_IDP
# ...

# %%
customer_info_failed.isnull().sum()
# Out:
# CUSTOMER_CODE                0
# CUSTOMER_DIVISION            0
# SAP_ID                    1211
# USER_DIVISION                0
# KCUST_ID                     0
# LOGIN_NAME                   0
# LAST_NAME                    0
# FIRST_NAME                   0
# COMPANY_NAME               677
# LOCATION                  1122
# DEPARTMENT                 816
# POSTAL_CODE                249
# ADDRESS1                   249
# ADDRESS2                   249
# ADDRESS3                   249
# ADDRESS4                   788
# PHONE                        3
# EXTENSION                 1210
# HOMEPHONE                 1007
# FAX                       1152
# MAILADDRESS                124
# GENDER                       0
# JOB_TITLE                 1211
# BIRTHDAY                   565
# SEND_MAIL                    0
# SAP_BILL_TO_ID            1211
# SAP_SHIP_TO_ID            1211
# SAP_PAYER_ID              1211
# OMS_DISCOUNT              1208
# PRICE_TYPE                1211
# ...

# %%
customer_info_processed  = pd.read_csv('/content/Customer_Information_20211118.csv',sep=chr(29), encoding='utf-8',names = CUS_COLUMNS)

# %%
customer_info_processed.isnull().sum()
# Out:
# CUSTOMER_CODE                0
# CUSTOMER_DIVISION            0
# SAP_ID                    1197
# USER_DIVISION                0
# KCUST_ID                     0
# LOGIN_NAME                   0
# LAST_NAME                    0
# FIRST_NAME                   0
# COMPANY_NAME               616
# LOCATION                  1098
# DEPARTMENT                 743
# POSTAL_CODE                222
# ADDRESS1                   222
# ADDRESS2                   222
# ADDRESS3                   222
# ADDRESS4                   772
# PHONE                        0
# EXTENSION                 1196
# HOMEPHONE                  995
# FAX                       1135
# MAILADDRESS                100
# GENDER                       0
# JOB_TITLE                 1195
# BIRTHDAY                   556
# SEND_MAIL                    0
# SAP_BILL_TO_ID            1197
# SAP_SHIP_TO_ID            1197
# SAP_PAYER_ID              1197
# OMS_DISCOUNT              1197
# PRICE_TYPE                1197
# ...

# %%
customer_info_processed[customer_info_processed['MAILADDRESS'].isnull()]
# Out:
#       CUSTOMER_CODE CUSTOMER_DIVISION  SAP_ID USER_DIVISION                  KCUST_ID           LOGIN_NAME LAST_NAME FIRST_NAME             COMPANY_NAME LOCATION DEPARTMENT POSTAL_CODE ADDRESS1 ADDRESS2    ADDRESS3 ADDRESS4          PHONE  EXTENSION HOMEPHONE  FAX MAILADDRESS    GENDER JOB_TITLE BIRTHDAY SEND_MAIL  SAP_BILL_TO_ID  SAP_SHIP_TO_ID  SAP_PAYER_ID  OMS_DISCOUNT  PRICE_TYPE USER_CREATE_DATE MODIFY_DATE  BACKLOGFLG  HP_SAP_SOLD_ID  HP_SAP_PAYER_ID  HP_BILL_TO_SAP_ID  HP_SHIP_TO_SAP_ID  EMPLOYEE_SCALE INDUSTRY   JOBTYPE MAIL_PERMIT FAX_PERMIT OPERATIONFLG      JOB CORPORATION CORPORATIONPOSITION LASTMODIFIED LASTNAMETRANSCRIPTION FIRSTNAMETRANSCRIPTION PERMITLASTMODIFIEDDATE  MASTERDPID  DEFAULTDPID HPIDDPLUS_USERNAME HPIDDPLUS_IDP
# ...

# %%
customer_info_processed.shape
# Out:
# (1197, 54)

# %%
customer_info_processed
# Out:
#       CUSTOMER_CODE CUSTOMER_DIVISION  SAP_ID USER_DIVISION                  KCUST_ID                  LOGIN_NAME LAST_NAME FIRST_NAME    COMPANY_NAME LOCATION DEPARTMENT POSTAL_CODE ADDRESS1 ADDRESS2        ADDRESS3        ADDRESS4          PHONE  EXTENSION      HOMEPHONE           FAX                   MAILADDRESS    GENDER JOB_TITLE    BIRTHDAY SEND_MAIL  SAP_BILL_TO_ID  SAP_SHIP_TO_ID  SAP_PAYER_ID  OMS_DISCOUNT  PRICE_TYPE USER_CREATE_DATE MODIFY_DATE  BACKLOGFLG  HP_SAP_SOLD_ID  HP_SAP_PAYER_ID  HP_BILL_TO_SAP_ID  HP_SHIP_TO_SAP_ID  EMPLOYEE_SCALE           INDUSTRY   JOBTYPE MAIL_PERMIT FAX_PERMIT OPERATIONFLG      JOB CORPORATION CORPORATIONPOSITION LASTMODIFIED LASTNAMETRANSCRIPTION FIRSTNAMETRANSCRIPTION PERMITLASTMODIFIEDDATE  MASTERDPID  DEFAULTDPID           HPIDDPLUS_USERNAME HPIDDPLUS_IDP
# ...

# %%
customer_info_enc  = pd.read_csv('/content/Customer_Information_20211118_enc.csv',sep=chr(29), encoding='utf-8')

# %%
customer_info_enc
# Out:
#                                           CUSTOMER_CODE CUSTOMER_DIVISION                                             SAP_ID USER_DIVISION                                           KCUST_ID                                         LOGIN_NAME                                          LAST_NAME                                         FIRST_NAME    COMPANY_NAME LOCATION DEPARTMENT POSTAL_CODE ADDRESS1                                           ADDRESS2                                           ADDRESS3                                           ADDRESS4                                              PHONE  EXTENSION                                          HOMEPHONE                                                FAX                                        MAILADDRESS                                             GENDER JOB_TITLE                                           BIRTHDAY                                          SEND_MAIL                                     SAP_BILL_TO_ID                 
# ...

# %% [markdown]
# ## NULL TOKENIZATION CHECK

# %%
customer_info_enc.iloc[240]['MAILADDRESS']
# Out:
# 'e720d934aca9b8436a569ae7221d1280983362a4931c2c81c67449ef13d6f5d8-QIT'

# %%
customer_info_enc[customer_info_enc['MAILADDRESS'] == 'e720d934aca9b8436a569ae7221d1280983362a4931c2c81c67449ef13d6f5d8-QIT']
# Out:
#                                           CUSTOMER_CODE CUSTOMER_DIVISION                                             SAP_ID USER_DIVISION                                           KCUST_ID                                         LOGIN_NAME                                          LAST_NAME                                         FIRST_NAME             COMPANY_NAME LOCATION DEPARTMENT POSTAL_CODE ADDRESS1                                           ADDRESS2                                           ADDRESS3                                           ADDRESS4                                              PHONE  EXTENSION                                          HOMEPHONE                                                FAX                                        MAILADDRESS                                             GENDER JOB_TITLE                                           BIRTHDAY                                          SEND_MAIL                                     SAP_BILL_TO_ID        
# ...

# %%
customer_info_processed.iloc[240]
# Out:
# CUSTOMER_CODE                             96891899
# CUSTOMER_DIVISION                               法人
# SAP_ID                                         NaN
# USER_DIVISION                               PLUS法人
# KCUST_ID                  RogPZEXC9vIAAAF5gFQuAu71
# LOGIN_NAME                     BackOffice000081869
# LAST_NAME                                     ご担当者
# FIRST_NAME                                       .
# COMPANY_NAME                        リーバイ・ストラウスジャパン
# LOCATION                                       NaN
# DEPARTMENT                                       .
# POSTAL_CODE                               150-0001
# ADDRESS1                                       東京都
# ADDRESS2                                       渋谷区
# ADDRESS3                                神宮前6-16-12
# ADDRESS4                                       NaN
# PHONE                                 03-5774-0501
# EXTENSION                                      NaN
# ...

# %%
customer_info_enc_failed  = pd.read_csv('/content/Customer_Information_20211218_enc.csv',sep=chr(29), encoding='utf-8')

# %%
customer_info_enc_failed
# Out:
#                                           CUSTOMER_CODE CUSTOMER_DIVISION                                             SAP_ID USER_DIVISION                                           KCUST_ID                                         LOGIN_NAME                                          LAST_NAME                                         FIRST_NAME   COMPANY_NAME LOCATION          DEPARTMENT POSTAL_CODE ADDRESS1                                           ADDRESS2                                           ADDRESS3                                           ADDRESS4                                              PHONE  EXTENSION                                          HOMEPHONE                                                FAX                                        MAILADDRESS                                             GENDER  JOB_TITLE                                           BIRTHDAY                                          SEND_MAIL                                     SAP_BILL_TO_ID        
# ...

# %%
customer_info_enc_failed[customer_info_enc_failed['MAILADDRESS'] == 'e720d934aca9b8436a569ae7221d1280983362a4931c2c81c67449ef13d6f5d8-QIT']
# Out:
#                                           CUSTOMER_CODE CUSTOMER_DIVISION                                             SAP_ID USER_DIVISION                                           KCUST_ID                                         LOGIN_NAME                                          LAST_NAME                                         FIRST_NAME        COMPANY_NAME LOCATION       DEPARTMENT POSTAL_CODE ADDRESS1                                           ADDRESS2                                           ADDRESS3                                           ADDRESS4                                              PHONE  EXTENSION                                          HOMEPHONE                                                FAX                                        MAILADDRESS                                             GENDER  JOB_TITLE                                           BIRTHDAY                                          SEND_MAIL                                     SAP_BILL_TO_ID      
# ...

# %%
customer_info_failed[customer_info_failed['MAILADDRESS'].isnull()]
# Out:
#       CUSTOMER_CODE CUSTOMER_DIVISION  SAP_ID USER_DIVISION                  KCUST_ID           LOGIN_NAME LAST_NAME FIRST_NAME        COMPANY_NAME LOCATION       DEPARTMENT POSTAL_CODE ADDRESS1 ADDRESS2    ADDRESS3 ADDRESS4          PHONE  EXTENSION HOMEPHONE  FAX MAILADDRESS    GENDER  JOB_TITLE BIRTHDAY SEND_MAIL  SAP_BILL_TO_ID  SAP_SHIP_TO_ID  SAP_PAYER_ID  OMS_DISCOUNT  PRICE_TYPE USER_CREATE_DATE MODIFY_DATE  BACKLOGFLG  HP_SAP_SOLD_ID  HP_SAP_PAYER_ID  HP_BILL_TO_SAP_ID  HP_SHIP_TO_SAP_ID  EMPLOYEE_SCALE INDUSTRY   JOBTYPE MAIL_PERMIT FAX_PERMIT OPERATIONFLG      JOB CORPORATION CORPORATIONPOSITION LASTMODIFIED LASTNAMETRANSCRIPTION FIRSTNAMETRANSCRIPTION PERMITLASTMODIFIEDDATE  MASTERDPID  DEFAULTDPID HPIDDPLUS_USERNAME HPIDDPLUS_IDP
# ...
