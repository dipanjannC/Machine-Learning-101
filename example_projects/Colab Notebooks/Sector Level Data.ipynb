# %%
import investpy
import pandas as pd
import numpy as np

# %%
stocks_df = investpy.get_stocks(country=None)

# %%
stocks_df
# Out:
#          country                      name  ... currency   symbol
# 0      argentina                   Tenaris  ...      ARS       TS
# 1      argentina              PETROBRAS ON  ...      ARS     APBR
# 2      argentina  Grupo Financiero Galicia  ...      ARS     GGAL
# 3      argentina         Ternium Argentina  ...      ARS     TXAR
# 4      argentina             Pampa Energia  ...      ARS     PAMP
# ...          ...                       ...  ...      ...      ...
# 39947   zimbabwe                   Padenga  ...      USD  PADENGA
# 39948   zimbabwe          Masimba Holdings  ...      USD     MSHL
# 39949   zimbabwe                Old Mutual  ...      USD      OMU
# 39950   zimbabwe               Proplastics  ...      USD     PROL
# 39951   zimbabwe          Cassava SmarTech  ...      ZWD     CSZL
#
# [39952 rows x 6 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-0b5e147c025c> in <module>()
# ----> 1 stocks_df[['name']=='Apple Inc']
#
# ...

# %%
stocks_list = investpy.get_stocks_list(country=None)

# %%
stocks_list
# Out:
# ['TS',
#  'APBR',
#  'GGAL',
#  'TXAR',
#  'PAMP',
#  'TECO2',
#  'BPAT',
#  'ALUA',
#  'BBAR',
#  'BMA',
#  'EDN',
#  'TRAN',
#  'MIRG',
#  'BHIP',
#  'AGRO',
#  'AUSO',
#  'GAMI',
#  'BOLT',
#  'CGPA2',
#  'CADO',
#  'CARC',
#  'CAPU',
#  'CECO2',
#  'CELU',
#  'CEPU',
#  'GCLA',
#  'COLO',
#  'COME',
#  'CTIO',
#  'CAPX',
#  'CRES',
#  'DYCA',
#  'DGCU2',
#  'FERR',
#  'FIPL',
#  'GARO',
#  'GBAN',
#  'GRIM',
#  'INDU',
#  'IRSA',
#  'HARG',
#  'LEDE',
#  'LONG',
#  'METR',
#  'MOLI',
#  'MORI',
#  'OEST',
#  'PATA',
#  'POLL',
#  'PSUR',
#  'PATY',
#  'RIGO',
#  'BRIO',
#  'ROSE',
#  'IRCP',
#  'SEMI',
#  'SAMI',
#  'TEF',
#  'TGNO4',
#  'TGSU2',
#  'YPFD',
#  'INVJ',
#  'CVX',
#  'C',
#  'BAC',
#  'T',
#  'CAT',
#  'INTC',
#  'MSFT',
#  'ARNC',
#  'DISN',
#  'CSCO',
#  'JPM',
#  'KMB',
#  'MCD',
#  'MRK',
#  'MMM',
#  'RDS',
#  'PHG',
#  'NVS',
#  'SIEGY',
#  'TOT',
#  'BBV',
#  'NOKA',
#  'BHP',
#  'SAP',
#  'AAPL',
#  'NGG',
#  'UN',
#  'CL',
#  'DD',
#  'PFE',
#  'WMT',
# ...
