# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("/content/Sample - Superstore.xls")
df.head()
# Out:
#    Row ID        Order ID Order Date  ... Quantity Discount    Profit
# 0       1  CA-2016-152156 2016-11-08  ...        2     0.00   41.9136
# 1       2  CA-2016-152156 2016-11-08  ...        3     0.00  219.5820
# 2       3  CA-2016-138688 2016-06-12  ...        2     0.00    6.8714
# 3       4  US-2015-108966 2015-10-11  ...        5     0.45 -383.0310
# 4       5  US-2015-108966 2015-10-11  ...        2     0.20    2.5164
#
# [5 rows x 21 columns]

# %%
df.nunique()
# Out:
# Row ID           9994
# Order ID         5009
# Order Date       1237
# Ship Date        1334
# Ship Mode           4
# Customer ID       793
# Customer Name     793
# Segment             3
# Country             1
# City              531
# State              49
# Postal Code       631
# Region              4
# Product ID       1862
# Category            3
# Sub-Category       17
# Product Name     1850
# Sales            6144
# Quantity           14
# Discount           12
# Profit           7545
# dtype: int64

# %%
df['SHIPPING TIME'] = abs(df['Ship Date'] - df['Order Date'])

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  ...    Profit AVG SHIPPING TIME SHIPPING TIME
# 0       1  CA-2016-152156 2016-11-08  ...   41.9136            3 days        3 days
# 1       2  CA-2016-152156 2016-11-08  ...  219.5820            3 days        3 days
# 2       3  CA-2016-138688 2016-06-12  ...    6.8714            4 days        4 days
# 3       4  US-2015-108966 2015-10-11  ... -383.0310            7 days        7 days
# 4       5  US-2015-108966 2015-10-11  ...    2.5164            7 days        7 days
#
# [5 rows x 23 columns]

# %%
max(df['SHIPPING TIME'])
# Out:
# Timedelta('7 days 00:00:00')

# %%
max_time = pd.DataFrame(df.groupby('Ship Mode').max()['SHIPPING TIME'])
max_time.sort_values(by=['SHIPPING TIME'], inplace=True, ascending=False)

# Top 20:
max_time.head(20)
# Out:
#                SHIPPING TIME
# Ship Mode
# Standard Class        7 days
# Second Class          5 days
# First Class           4 days
# Same Day              1 days

# %%
df['SHIPPING TIME'].mean()
# Out:
# Timedelta('3 days 22:59:46.311787072')
