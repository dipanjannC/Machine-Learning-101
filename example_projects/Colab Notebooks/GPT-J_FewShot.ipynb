# %%
# !git clone https://github.com/tonyzhaozh/few-shot-learning.git
# Out:
# Cloning into 'few-shot-learning'...
# remote: Enumerating objects: 234, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 234 (delta 4), reused 3 (delta 0), pack-reused 221
# Receiving objects: 100% (234/234), 111.77 MiB | 16.02 MiB/s, done.
# Resolving deltas: 100% (6/6), done.
# Checking out files: 100% (168/168), done.
